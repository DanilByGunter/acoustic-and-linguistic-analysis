# %% [markdown]
# # Download feature extractors classes

# %%
from acoustic_extractor import AcousticExtractor
from mfcc_extractor import MFCCExtractor
from linguistic_extractor import LinguisticExtractor
from helpers.data_loader import ResourceLoader

# %% [markdown]
# # Init feature extractors classes

# %% [markdown]
# Init resources (for linguistic extractor)

# %%
resources = ResourceLoader("resources/")

# %% [markdown]
# Init audio feature extractor

# %%
acoustic = AcousticExtractor(analysis_mode='cumulative', window_size=10, step_size=5)

# %% [markdown]
# Token from: https://huggingface.co/pyannote/speaker-diarization-3.1
# Init mfcc feature extractor

# %%
mfcc = MFCCExtractor(hf_token='', analysis_mode='cumulative', window_size=10, step_size=5)

# %% [markdown]
# Init lunguistic feature extractor

# %%
linguistic = LinguisticExtractor(resources, analysis_mode='cumulative', window_size=10, step_size=5)
# Out:
# Fetching 1 files: 100%|██████████| 1/1 [00:00<?, ?it/s]

# %% [markdown]
# # Extract feature

# %% [markdown]
# Audio path

# %%
audio_path = 'test.wav'

# %% [markdown]
# Extract mfcc

# %%
result_mfcc = mfcc.extract_from_path(audio_path)

# %%
result_mfcc
# Out:
#     start_sec  end_sec    MFCC_1    MFCC_2    MFCC_3    MFCC_4    MFCC_5  \
# 0         0.0     10.0  0.355164  3.233197  3.230254  3.046997  2.857037
# 1         0.0     15.0  1.017006  3.888792  3.695196  3.435565  3.440895
# 2         0.0     20.0  1.330713  4.062979  3.809397  3.783383  3.658603
# 3         0.0     25.0  1.236157  3.894382  3.586654  3.471660  3.349267
# 4         0.0     30.0  1.304489  3.913650  3.575458  3.520727  3.361608
# 5         0.0     35.0  1.304489  3.913650  3.575458  3.520727  3.361608
# 6         0.0     40.0  1.303246  3.805156  3.382882  3.425913  3.245037
# 7         0.0     45.0  1.367783  3.823135  3.393838  3.425158  3.227470
# 8         0.0     50.0  1.314442  3.761310  3.348367  3.399963  3.181057
# 9         0.0     55.0  1.285381  3.758010  3.335590  3.369169  3.139009
# 10        0.0     60.0  1.193281  3.596317  3.147851  3.249307  2.993445
#
#       MFCC_6    MFCC_7    MFCC_8  ...  Delta2_55  Delta2_56  Delta2_57  \
# ...

# %% [markdown]
# Extract acoustic

# %%
result_acoustic = acoustic.extract_from_path(audio_path)

# %%
result_acoustic
# Out:
#     voiced_fraction  pause_total_time  pause_ratio  pause_count  \
# 0          0.922000              0.78     0.078000            4
# 1          0.908000              1.38     0.092000            6
# 2          0.881500              2.37     0.118500            9
# 3          0.890800              2.73     0.109200           11
# 4          0.880000              3.60     0.120000           14
# 5          0.858571              4.95     0.141429           20
# 6          0.874000              5.04     0.126000           21
# 7          0.874000              5.67     0.126000           23
# 8          0.880000              6.00     0.120000           24
# 9          0.888182              6.15     0.111818           25
# 10         0.891500              6.51     0.108500           26
#
#     pause_frequency  pause_duration_mean  pause_duration_median  \
# 0         24.000000             0.195000                  0.210
# 1         24.000000             0.230000                  0.285
# ...

# %% [markdown]
# Extract linguistic

# %%
result_linguistic = linguistic.extract_from_path(audio_path)

# %%
result_linguistic
# Out:
#                                              text_str  speed_speech_mean  \
# 0   Пишите ваше самочувствие сейчас. Самочувствие ...         120.000000
# 1   Пишите ваше самочувствие сейчас. Самочувствие ...         108.000000
# 2   Пишите ваше самочувствие сейчас. Самочувствие ...         104.669604
# 3   Пишите ваше самочувствие сейчас. Самочувствие ...         110.383275
# 4   Пишите ваше самочувствие сейчас. Самочувствие ...         109.940120
# 5   Пишите ваше самочувствие сейчас. Самочувствие ...         113.597246
# 6   Пишите ваше самочувствие сейчас. Самочувствие ...         112.775330
# 7   Пишите ваше самочувствие сейчас. Самочувствие ...         115.725456
# 8   Пишите ваше самочувствие сейчас. Самочувствие ...         109.300538
# 9   Пишите ваше самочувствие сейчас. Самочувствие ...         114.128187
# 10  Пишите ваше самочувствие сейчас. Самочувствие ...         119.175515
# 11  Пишите ваше самочувствие сейчас. Самочувствие ...         120.224719
#
# ...
